# %%
import pandas as pd

# %%
df = pd.read_csv('./step_4_DE.csv')
df
# Out:
#      index  Target_ID   Target_Class  Frame   Px   Py           Wx  \
# 0       47          1         person     50  582   64   319.121823
# 1       89          1         person    100  584   60   205.065997
# 2      158          2  bicycleperson     50  757  135   996.895842
# 3      198          2  bicycleperson     90  757  135   996.895842
# 4      208          2  bicycleperson    100  756  135   997.245973
# ..     ...        ...            ...    ...  ...  ...          ...
# 983  26817        538         person   5510  528  130  1049.625376
# 984  26827        538         person   5520  540  111   945.868114
# 985  26837        538         person   5530  549  144  1098.476307
# 986  26839        538         person   5540  541  170  1176.801646
# 987  26849        538         person   5550  546  160  1149.584499
#
#              Wy   Time      RWx_m  ...        Vx        Vy        ax  \
# 0    164.654382    5.0   6.554195  ... -1.295475  0.009179  0.000000
# ...

# %%
len(set(df['Target_ID']))
# Out:
# 94
